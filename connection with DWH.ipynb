# %%
import pandas as pd

# Load CSV file
df = pd.read_csv(r"C:\dwh project\transactional_data_preprocessed.csv")

# Show first few rows
print(df.head())

# Show data types of each column
print(df.dtypes)
# Out:
#    orderID  Customer_ID Product_ID  quantity        date
# 0  9914432      1000001  P00069042         1  2020-12-29
# 1  1676537      1000001  P00248942         3  2017-03-27
# 2  8910457      1000001  P00087842         1  2017-08-20
# 3  5044982      1000001  P00085442         1  2019-03-03
# 4  4176351      1000002  P00285442         1  2018-07-11
# orderID         int64
# Customer_ID     int64
# Product_ID     object
# quantity        int64
# date           object
# dtype: object

# %%
import psycopg2
import pandas as pd

# PostgreSQL connection
conn = psycopg2.connect(
    host="localhost",
    database="starflake",
    user="postgres",
    password="mahnoor333",
    port="5432"
)

print("Connected to PostgreSQL successfully!")

# Create cursor
cursor = conn.cursor()
# Out:
# Connected to PostgreSQL successfully!
